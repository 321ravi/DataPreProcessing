# %% [markdown]
# # IMPORT LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # IMPORTING DATASET

# %%
Data = pd.read_excel('hourlydataten.xlsx')
Data.head()
# Out:
#                  time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0 2014-01-01 05:00:00                 14.9                        63
# 1 2014-01-01 06:00:00                 16.1                        60
# 2 2014-01-01 07:00:00                 16.0                        64
# 3 2014-01-01 08:00:00                 16.0                        64
# 4 2014-01-01 09:00:00                 16.1                        65
#
#    dew_point_2m (°C)  apparent_temperature (°C)  precipitation (mm)  \
# 0                8.0                       14.1                 0.0
# 1                8.4                       15.1                 0.0
# 2                9.2                       15.0                 0.0
# 3                9.2                       14.9                 0.0
# 4                9.4                       14.8                 0.0
#
#    rain (mm)  snowfall (cm)  pressure_msl (hPa)  surface_pressure (hPa)  ...  \
# ...

# %%
Data['Date'] = dataframe['time'].dt.date
wdata = dataframe.groupby('Date').mean()
wdata = wdata.drop(columns=['time'])
wdata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Data['Date'] = dataframe['time'].dt.date
#       2 wdata = dataframe.groupby('Date').mean()
#       3 wdata = wdata.drop(columns=['time'])
#
# NameError: name 'dataframe' is not defined
